# %% [markdown]
# # DataCleaning
# ------
# - Cleaning Data Science Salaries CSV (dropping all Part Time / Free Lance / and CT Employee Data because they make up only 2% of the Data)

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("ds_salaries.csv")
data.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# 2                 GB            50               GB            M
# 3                 HN             0               HN            S
# 4                 US            50               US            L

# %%
data.employment_type.describe()
# Out:
# count     607
# unique      4
# top        FT
# freq      588
# Name: employment_type, dtype: object

# %%
data.employment_type.unique()
# Out:
# array(['FT', 'CT', 'PT', 'FL'], dtype=object)

# %%
fullTime = data.loc[data["employment_type"] == "FT"].copy()
fullTime
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# 3          Product Data Analyst   20000             USD          20000
# 4     Machine Learning Engineer  150000             USD         150000
# ..                          ...     ...             ...            ...
# 602               Data Engineer  154000             USD         154000
# 603               Data Engineer  126000             USD         126000
# 604                Data Analyst  129000             USD         129000
# 605                Data Analyst  150000             USD         150000
# 606                AI Scientist  200000             USD         200000
#
#     employee_residence  remote_ratio company_location company_size
# 0                   DE             0               DE            L
# 1                   JP             0               JP            S
# 2                   GB            50               GB            M
# 3                   HN             0               HN            S
# 4                   US            50               US            L
# ..                 ...           ...              ...          ...
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US             0               US            M
# 605                 US           100               US            M
# 606                 IN           100               US            L
#
# [588 rows x 12 columns]

# %%
# Rename unamed column
fullTime.rename(columns={"Unnamed: 0": "id"}, inplace=True)
fullTime
# Out:
#       id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1      1       2020               SE              FT
# 2      2       2020               SE              FT
# 3      3       2020               MI              FT
# 4      4       2020               SE              FT
# ..   ...        ...              ...             ...
# 602  602       2022               SE              FT
# 603  603       2022               SE              FT
# 604  604       2022               SE              FT
# 605  605       2022               SE              FT
# 606  606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# 3          Product Data Analyst   20000             USD          20000
# 4     Machine Learning Engineer  150000             USD         150000
# ..                          ...     ...             ...            ...
# 602               Data Engineer  154000             USD         154000
# 603               Data Engineer  126000             USD         126000
# 604                Data Analyst  129000             USD         129000
# 605                Data Analyst  150000             USD         150000
# 606                AI Scientist  200000             USD         200000
#
#     employee_residence  remote_ratio company_location company_size
# 0                   DE             0               DE            L
# 1                   JP             0               JP            S
# 2                   GB            50               GB            M
# 3                   HN             0               HN            S
# 4                   US            50               US            L
# ..                 ...           ...              ...          ...
# 602                 US           100               US            M
# 603                 US           100               US            M
# 604                 US             0               US            M
# 605                 US           100               US            M
# 606                 IN           100               US            L
#
# [588 rows x 12 columns]

# %%
# To Csv
fullTime.to_csv("FullTimeEmployeeData.csv", encoding='utf-8', index=False)

# %%
fullTime.company_location.unique()
# Out:
# array(['DE', 'JP', 'GB', 'HN', 'US', 'HU', 'NZ', 'FR', 'IN', 'PK', 'CN',
#        'GR', 'AE', 'NL', 'MX', 'CA', 'AT', 'NG', 'ES', 'PT', 'DK', 'HR',
#        'LU', 'PL', 'SG', 'RO', 'IQ', 'BR', 'BE', 'UA', 'IL', 'RU', 'MT',
#        'CL', 'IR', 'CO', 'MD', 'KE', 'SI', 'CH', 'VN', 'AS', 'TR', 'CZ',
#        'IT', 'EE', 'MY', 'AU', 'IE'], dtype=object)

# %%
# country codes csv
countryCodes = pd.read_csv("https://gist.githubusercontent.com/radcliff/f09c0f88344a7fcef373/raw/2753c482ad091c54b1822288ad2e4811c021d8ec/wikipedia-iso-country-codes.csv")
countryCodes.head()
# Out:
#   English short name lower case Alpha-2 code Alpha-3 code  Numeric code  \
# 0                   Afghanistan           AF          AFG             4
# 1                 Åland Islands           AX          ALA           248
# 2                       Albania           AL          ALB             8
# 3                       Algeria           DZ          DZA            12
# 4                American Samoa           AS          ASM            16
#
#       ISO 3166-2
# 0  ISO 3166-2:AF
# 1  ISO 3166-2:AX
# 2  ISO 3166-2:AL
# 3  ISO 3166-2:DZ
# 4  ISO 3166-2:AS

# %%
cleanCodes = countryCodes[['Alpha-2 code', 'English short name lower case']].copy()
cleanCodes
# Out:
#     Alpha-2 code English short name lower case
# 0             AF                   Afghanistan
# 1             AX                 Åland Islands
# 2             AL                       Albania
# 3             DZ                       Algeria
# 4             AS                American Samoa
# ..           ...                           ...
# 241           WF             Wallis and Futuna
# 242           EH                Western Sahara
# 243           YE                         Yemen
# 244           ZM                        Zambia
# 245           ZW                      Zimbabwe
#
# [246 rows x 2 columns]

# %%
cleanCodes.rename(columns={"Alpha-2 code": "company_location", "English short name lower case": "country_name"}, inplace=True)
cleanCodes
# Out:
#     company_location       country_name
# 0                 AF        Afghanistan
# 1                 AX      Åland Islands
# 2                 AL            Albania
# 3                 DZ            Algeria
# 4                 AS     American Samoa
# ..               ...                ...
# 241               WF  Wallis and Futuna
# 242               EH     Western Sahara
# 243               YE              Yemen
# 244               ZM             Zambia
# 245               ZW           Zimbabwe
#
# [246 rows x 2 columns]

# %%
cleanFTdata = pd.merge(fullTime, cleanCodes, on='company_location', how='inner')
cleanFTdata
# Out:
#       id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1     30       2020               MI              FT
# 2     53       2020               EN              FT
# 3     55       2020               SE              FT
# 4     65       2020               EN              FT
# ..   ...        ...              ...             ...
# 583  502       2022               EN              FT
# 584  503       2022               MI              FT
# 585  505       2022               EN              FT
# 586  510       2022               EN              FT
# 587  513       2022               SE              FT
#
#                              job_title  salary salary_currency  salary_in_usd  \
# 0                       Data Scientist   70000             EUR          79833
# 1             Data Engineering Manager   51999             EUR          59303
# 2                        Data Engineer   48000             EUR          54742
# 3             Principal Data Scientist  130000             EUR         148261
# 4                       Data Scientist   55000             EUR          62726
# ..                                 ...     ...             ...            ...
# 583                     Data Scientist   40000             USD          40000
# 584          Machine Learning Engineer  121000             AUD          87425
# 585                     Data Scientist  120000             AUD          86703
# 586  Computer Vision Software Engineer  150000             USD         150000
# 587          Machine Learning Engineer   65000             EUR          71444
#
#     employee_residence  remote_ratio company_location company_size  \
# 0                   DE             0               DE            L
# 1                   DE           100               DE            S
# 2                   PK           100               DE            L
# 3                   DE           100               DE            M
# 4                   DE            50               DE            S
# ..                 ...           ...              ...          ...
# 583                 JP           100               MY            L
# 584                 AU           100               AU            L
# 585                 AU            50               AU            M
# 586                 AU           100               AU            S
# 587                 IE           100               IE            S
#
#     country_name
# 0        Germany
# 1        Germany
# 2        Germany
# 3        Germany
# 4        Germany
# ..           ...
# 583     Malaysia
# 584    Australia
# 585    Australia
# 586    Australia
# 587      Ireland
#
# [588 rows x 13 columns]

# %%
# to csv
cleanFTdata.to_csv('CleanFullTimeData.csv', encoding='utf-8', index=False)
cleanCodes.to_csv('CountryCodeData.csv', encoding='utf-8', index=False)
